# %%
import IPython.display as ipd
import os
os.system('rm -f tmp.mp4')
file_name='/DCAIOCTO/ModelDataZoo/datasets/AMD_data/WIP_vids/IA_00395/436501_1495972_2021-05-12_16-46-38_R/AIA_00395_OD.avi'
cmd=['ffmpeg -i', file_name, 'tmp.mp4']
os.system(' '.join(cmd))
ipd.Video('tmp.mp4', width=480)

# %%
from moviepy.editor import *
file_name='/DCAIOCTO/ModelDataZoo/datasets/AMD_data/WIP_vids_no_Fund/IA_04215/314725_1082099_2019-07-17_12-33-16_R/AIA_04215_OD.avi'
clip=VideoFileClip(file_name)
print("number of frames=",clip.reader.nframes)
clip.ipython_display(width=720)
# Out:
# 38
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video width='720'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
import IPython.display as ipd
import os
dir_name = '/DCAIOCTO/ModelDataZoo/datasets/AMD_data/fundus_DB/train/4/'
for i,file_name in enumerate(os.listdir(dir_name)):
    file_full_path = os.path.join(dir_name, file_name)
    x= ipd.Image(file_full_path, width=480)
    ipd.display(x)
